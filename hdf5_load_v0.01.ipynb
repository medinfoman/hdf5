# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage
# from hdf5_load import *

# %matplotlib inline

# %%
# y
f = h5py.File('./data.hdf5', "r")
train_x = np.array(f["train_x"][:])
train_y = np.array(f["train_y"][:])
print(f["train_y"][:])
# Out:
# [0. 0. 0. 0. 1.]

# %%
# Example of your image data
index = 1
example = train_x[index]

img = Image.fromarray(example, 'RGB')

oneImage = np.array(example) # image to array

plt.imshow(example)

print("Class: ", train_y[index])
# Out:
# Class:  0.0
